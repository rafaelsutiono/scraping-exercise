# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd


# downloading CNA data
headers = {'Accept-Language': 'en-US,en;q=0.8'}
url = 'https://www.channelnewsasia.com/international'
response = requests.get(url,headers=headers)
soup = BeautifulSoup(response.text, "html.parser")


article_title = []
link = []
category = []
uuid = []
nid = []


for l in soup.select('div.quick-link--list-object'):
    # extract specific attributes from the div
    titletext = l['data-heading']
    linktext = l['data-link_absolute']
    categorytext = l['data-category']
    uuidtext = l['data-uuid']
    nidtext = l['data-nid']
    article_title.append(titletext)
    link.append(linktext)
    category.append(categorytext)
    uuid.append(uuidtext)
    nid.append(nidtext)

print(article_title)
print(link)
print(category)
print(uuid)
print(nid)
# Out:
# ['At UN General Assembly, Biden asks world to stand by Ukraine', 'China asks consulates in Hong Kong to give details on local staff', "'Cybersecurity incident' hits International Criminal Court", 'Putin and Xi to meet in Beijing in October, Russia says ', 'Climate change, conflict made Libya deluge more likely: Study', 'China files appeal against WTO panel report on US steel, aluminium tariffs', 'UK says no evidence of political bank account closures', 'Philippines activists freed after alleged military abduction', 'Putin and Xi to meet in Beijing in October, Russia says ', 'At UN General Assembly, Biden asks world to stand by Ukraine', "Strained ties between India, Canada hit 'new low' after accusation of Sikh leader's murder", 'What to know about the Sikh movement at the centre of tensions between India and Canada', "'Cybersecurity incident' hits International Criminal Court", "China's ex-foreign minister Qin Gang was ousted after alleged affair: Report", 'Dermal fillers and blindn
# ...

# %%
df = pd.DataFrame(
    {'Article Title': article_title, 'Link': link, 'Category': category, 'UUID': uuid, 'NID': nid}
    )

print (df.head())

df.to_csv('CNAarticles.csv', index=False)
# Out:
#                                        Article Title  \
# 0  At UN General Assembly, Biden asks world to st...
# 1  China asks consulates in Hong Kong to give det...
# 2  'Cybersecurity incident' hits International Cr...
# 3  Putin and Xi to meet in Beijing in October, Ru...
# 4  Climate change, conflict made Libya deluge mor...
#
#                                                 Link Category  \
# 0  https://www.channelnewsasia.com/world/un-gener...    World
# 1  https://www.channelnewsasia.com/asia/china-ask...     Asia
# 2  https://www.channelnewsasia.com/world/cybersec...    World
# 3  https://www.channelnewsasia.com/world/putin-xi...    World
# 4  https://www.channelnewsasia.com/world/libya-fl...    World
#
#                                    UUID      NID
# 0  fb6dadd5-a20b-46ec-a942-acee3bdcad81  3782196
# 1  46dd6d6b-c919-43ee-8392-46e8564abc2c  3783196
# 2  b58d6f20-95b9-45d6-818d-b2c981b091e0  3783211
# 3  4e3ec05a-db5a-4a2e-b8a0-a7227ffcde70  3782246
# ...
